# %%
# %reload_ext autoreload
# %autoreload 2

import sys
import os

# Add the parent directory to the path
sys.path.append(os.path.dirname(os.getcwd()))

from infodump_tools.calculate import load_dfs

# %%
(
    joinyears,
    df_users,
    df_posts_all,
    df_comments_all,
    df_activity_all,
) = load_dfs("../infodump")
# Out:
# Oldest file is ../infodump/commentdata_fanfare.txt: 2026-02-08 11:40:02
# Loaded files into dataframes

# %%
df_users
# Out:
# shape: (77_040, 5)
# ┌─────────┬─────────────────────┬────────────┬──────────┬────────────┐
# │ userid  ┆ joindate            ┆ name       ┆ joinyear ┆ joinmonth  │
# │ ---     ┆ ---                 ┆ ---        ┆ ---      ┆ ---        │
# │ u32     ┆ datetime[ms]        ┆ str        ┆ i32      ┆ date       │
# ╞═════════╪═════════════════════╪════════════╪══════════╪════════════╡
# │ 1       ┆ 1999-07-14 15:03:04 ┆ mathowie   ┆ 1999     ┆ 1999-07-01 │
# │ 8       ┆ 2000-01-27 20:16:57 ┆ OneBallJay ┆ 2000     ┆ 2000-01-01 │
# │ 13      ┆ 2000-01-27 20:16:57 ┆ jeffp      ┆ 2000     ┆ 2000-01-01 │
# │ 16      ┆ 1999-07-15 09:54:26 ┆ jjg        ┆ 1999     ┆ 1999-07-01 │
# │ 17      ┆ 1999-07-15 11:45:47 ┆ honkzilla  ┆ 1999     ┆ 1999-07-01 │
# │ …       ┆ …                   ┆ …          ┆ …        ┆ …          │
# │ 1292425 ┆ 2015-08-12 14:41:18 ┆ null       ┆ 2015     ┆ 2015-08-01 │
# │ 2923838 ┆ 2018-08-21 16:37:12 ┆ null       ┆ 2018     ┆ 2018-08-01 │
# ...
